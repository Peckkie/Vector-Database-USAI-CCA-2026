# %%
import pandas as pd
Results_Unlearn  = './Evaluation_Results_Unlearn_K5.csv'
# test = '/home/yupaporn/codes/USAI/Testdf.csv'
Results_Unlearn = pd.read_csv (Results_Unlearn)

Results_Unlearn.head()
# Out:
#                                            Path Crop Sub_class_New  \
# 0  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...          AB01
# 1  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...          AB01
# 2  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...          AB01
# 3  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...          AB01
# 4  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...          AB01
#
#   Sub_Position_Label                          Path Crop_match_train_all  \
# 0                 P1  ['/media/tohn/HDD/VISION_dataset/USAI/ABnormal...
# 1                 P2  ['/media/tohn/HDD/VISION_dataset/USAI/ABnormal...
# 2                 P4  ['/media/tohn/HDD/VISION_dataset/USAI/ABnormal...
# 3                 P6  ['/media/tohn/HDD/VISION_dataset/USAI/ABnormal...
# 4                 P3  ['/media/tohn/HDD/VISION_dataset/USAI/ABnormal...
#
#           Sub_class_Unlearn_match_train_all  \
# 0  ['AB02', 'AB02', 'AB01', 'AB02', 'AB02']
# 1  ['AB01', 'AB01', 'AB01', 'AB01', 'AB01']
# 2  ['AB01', 'AB01', 'AB01', 'AB01', 'AB01']
# 3  ['AB01', 'AB01', 'AB01', 'AB02', 'AB01']
# 4  ['AB02', 'AB01', 'AB02', 'AB01', 'AB01']
#
#   Sub_Position_Unlearn_match_train_all Unlearn_pred_15AB_top1  \
# 0       ['P2', 'P2', 'P5', 'P2', 'P1']                   AB02
# 1       ['P2', 'P2', 'P7', 'P2', 'P2']                   AB01
# 2       ['P2', 'P5', 'P2', 'P1', 'P3']                   AB01
# 3       ['P1', 'P5', 'P7', 'P2', 'P6']                   AB01
# 4       ['P2', 'P1', 'P2', 'P2', 'P2']                   AB02
#
#   Unlearn_pred_Sub_Position_top1  Distance_top1 Unlearn_pred_15AB_top2  ...  \
# 0                             P2      14.979928                   AB02  ...
# 1                             P2      11.600711                   AB01  ...
# 2                             P2      11.371438                   AB01  ...
# 3                             P1       8.766629                   AB01  ...
# 4                             P2       9.048177                   AB01  ...
#
#   Distance_top3  Unlearn_pred_15AB_top4 Unlearn_pred_Sub_Position_top4  \
# 0     15.148824                    AB02                             P2
# 1     12.181795                    AB01                             P2
# 2     12.751753                    AB01                             P1
# 3     10.531213                    AB02                             P2
# 4     11.434771                    AB01                             P2
#
#   Distance_top4  Unlearn_pred_15AB_top5 Unlearn_pred_Sub_Position_top5  \
# 0     15.436083                    AB02                             P1
# 1     12.235053                    AB01                             P2
# 2     13.345594                    AB01                             P3
# 3     10.578455                    AB01                             P6
# 4     11.967776                    AB01                             P2
#
#   Distance_top5                     Unlearn_prob_15AB_all  \
# 0     15.517820  ['AB02', 'AB02', 'AB01', 'AB02', 'AB02']
# 1     12.238633  ['AB01', 'AB01', 'AB01', 'AB01', 'AB01']
# 2     13.486195  ['AB01', 'AB01', 'AB01', 'AB01', 'AB01']
# 3     10.734092  ['AB01', 'AB01', 'AB01', 'AB02', 'AB01']
# 4     12.271632  ['AB02', 'AB01', 'AB02', 'AB01', 'AB01']
#
#     Unlearn_prob_Sub_Position_all  \
# 0  ['P2', 'P2', 'P5', 'P2', 'P1']
# 1  ['P2', 'P2', 'P7', 'P2', 'P2']
# 2  ['P2', 'P5', 'P2', 'P1', 'P3']
# 3  ['P1', 'P5', 'P7', 'P2', 'P6']
# 4  ['P2', 'P1', 'P2', 'P2', 'P2']
#
#                                 Unlearn_Distance_all
# 0  [14.979928406085408, 15.123628138786462, 15.14...
# 1  [11.600711356122158, 11.843067663077202, 12.18...
# 2  [11.371437974450265, 12.399059167629508, 12.75...
# 3  [8.766628802302847, 10.179570352398047, 10.531...
# 4  [9.048177053987287, 10.432528223009443, 11.434...
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Evaluation Top-1

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# =========================
# Ground truth
# =========================
y_true_15AB = Results_Unlearn['Sub_class_New']
y_true_pos  = Results_Unlearn['Sub_Position_Label']

# =========================
# Top-1 predictions
# =========================
y_pred_15AB = Results_Unlearn['Unlearn_pred_15AB_top1']
y_pred_pos  = Results_Unlearn['Unlearn_pred_Sub_Position_top1']

# =========================
# 15AB metrics
# =========================
acc_15AB = accuracy_score(y_true_15AB, y_pred_15AB)
prec_15AB = precision_score(y_true_15AB, y_pred_15AB, average='macro', zero_division=0)
rec_15AB = recall_score(y_true_15AB, y_pred_15AB, average='macro', zero_division=0)
f1_15AB = f1_score(y_true_15AB, y_pred_15AB, average='macro', zero_division=0)

# =========================
# Sub-Position metrics
# =========================
acc_pos = accuracy_score(y_true_pos, y_pred_pos)
prec_pos = precision_score(y_true_pos, y_pred_pos, average='macro', zero_division=0)
rec_pos = recall_score(y_true_pos, y_pred_pos, average='macro', zero_division=0)
f1_pos = f1_score(y_true_pos, y_pred_pos, average='macro', zero_division=0)

# =========================
# Print results
# =========================
print("===== 15AB Classification (Top-1) =====")
print(f"Accuracy : {acc_15AB:.4f}")
print(f"Precision: {prec_15AB:.4f}")
print(f"Recall   : {rec_15AB:.4f}")
print(f"F1-score : {f1_15AB:.4f}")

print("\n===== Sub-Position Classification (Top-1) =====")
print(f"Accuracy : {acc_pos:.4f}")
print(f"Precision: {prec_pos:.4f}")
print(f"Recall   : {rec_pos:.4f}")
print(f"F1-score : {f1_pos:.4f}")
# Out:
# ===== 15AB Classification (Top-1) =====
# Accuracy : 0.8720
# Precision: 0.7478
# Recall   : 0.7137
# F1-score : 0.7213
#
# ===== Sub-Position Classification (Top-1) =====
# Accuracy : 0.4657
# Precision: 0.4427
# Recall   : 0.4484
# F1-score : 0.4416

# %% [markdown]
# ## Evaluation Top-3

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np

def topk_metrics(df, gt_col, pred_cols, k):
    y_true = []
    y_pred = []

    for i in range(len(df)):
        gt = df.loc[i, gt_col]
        preds = df.loc[i, pred_cols[:k]].values.tolist()

        if gt in preds:
            y_true.append(1)
            y_pred.append(1)
        else:
            y_true.append(1)
            y_pred.append(0)

    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, zero_division=0)
    rec = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)

    return acc, prec, rec, f1

# %% [markdown]
# ### 15AB : Top-3 / Top-5

# %%
pred_15AB_columns_top5 = [
    'Unlearn_pred_15AB_top1',
    'Unlearn_pred_15AB_top2',
    'Unlearn_pred_15AB_top3',
    'Unlearn_pred_15AB_top4',
    'Unlearn_pred_15AB_top5'
]

acc3_15AB, prec3_15AB, rec3_15AB, f13_15AB = topk_metrics(
    Results_Unlearn,
    gt_col='Sub_class_New',
    pred_cols=pred_15AB_columns_top5,
    k=3
)

acc5_15AB, prec5_15AB, rec5_15AB, f15_15AB = topk_metrics(
    Results_Unlearn,
    gt_col='Sub_class_New',
    pred_cols=pred_15AB_columns_top5,
    k=5
)

# %% [markdown]
# ### Sub-Position : Top-3 / Top-5

# %%
pred_Sub_Position_columns_top5 = [
    'Unlearn_pred_Sub_Position_top1',
    'Unlearn_pred_Sub_Position_top2',
    'Unlearn_pred_Sub_Position_top3',
    'Unlearn_pred_Sub_Position_top4',
    'Unlearn_pred_Sub_Position_top5'
]

acc3_pos, prec3_pos, rec3_pos, f13_pos = topk_metrics(
    Results_Unlearn,
    gt_col='Sub_Position_Label',
    pred_cols=pred_Sub_Position_columns_top5,
    k=3
)

acc5_pos, prec5_pos, rec5_pos, f15_pos = topk_metrics(
    Results_Unlearn,
    gt_col='Sub_Position_Label',
    pred_cols=pred_Sub_Position_columns_top5,
    k=5
)

# %%
print("===== 15AB Classification =====")
print(f"Top-3 | Acc: {acc3_15AB:.4f}  Prec: {prec3_15AB:.4f}  Rec: {rec3_15AB:.4f}  F1: {f13_15AB:.4f}")
print(f"Top-5 | Acc: {acc5_15AB:.4f}  Prec: {prec5_15AB:.4f}  Rec: {rec5_15AB:.4f}  F1: {f15_15AB:.4f}")

print("\n===== Sub-Position Classification =====")
print(f"Top-3 | Acc: {acc3_pos:.4f}  Prec: {prec3_pos:.4f}  Rec: {rec3_pos:.4f}  F1: {f13_pos:.4f}")
print(f"Top-5 | Acc: {acc5_pos:.4f}  Prec: {prec5_pos:.4f}  Rec: {rec5_pos:.4f}  F1: {f15_pos:.4f}")
# Out:
# ===== 15AB Classification =====
# Top-3 | Acc: 0.9261  Prec: 1.0000  Rec: 0.9261  F1: 0.9616
# Top-5 | Acc: 0.9360  Prec: 1.0000  Rec: 0.9360  F1: 0.9669
#
# ===== Sub-Position Classification =====
# Top-3 | Acc: 0.6966  Prec: 1.0000  Rec: 0.6966  F1: 0.8212
# Top-5 | Acc: 0.8049  Prec: 1.0000  Rec: 0.8049  F1: 0.8919

# %% [markdown]
# ##  Top-k Confusion Matrix (15×15)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Ground truth & prediction (Top-1)
y_true = Results_Unlearn['Sub_class_New']
y_pred = Results_Unlearn['Unlearn_pred_15AB_top1']

# fix label order (สำคัญมาก)
labels_15AB = sorted(y_true.unique())

cm = confusion_matrix(y_true, y_pred, labels=labels_15AB, normalize='true')

plt.figure(figsize=(10,8))
sns.heatmap(
    cm,
    xticklabels=labels_15AB,
    yticklabels=labels_15AB,
    cmap="Blues",
    annot=False
)
plt.xlabel("Predicted label")
plt.ylabel("Ground truth label")
plt.title("15-class Confusion Matrix (Top-1, normalized)")
plt.tight_layout()
plt.show()

# %% [raw]
# 1️⃣ อ่าน Top-1 Confusion Matrix นี้ก่อน
# ภาพรวม
#
# Diagonal (เส้นทแยง) ค่อนข้างชัดหลาย class
# 👉 โมเดล “จำ class หลักได้”
#
# แต่มี การกระจายไป class ข้างเคียง ชัดในบางกลุ่ม
#
# กลุ่มที่ Top-1 แข็งแรง
#
# AB05, AB09, AB10, AB11, AB12, Normal
#
# diagonal เข้ม
#
# confusion ต่ำ
#
# 👉 Top-k แทบไม่ช่วย (ตรงกับ ΔRecall = 0)
# กลุ่มที่ Top-1 ยังสับสน
#
# เห็นชัดมาก:
#
# AB01 ↔ AB02 ↔ AB03
#
# AB06 ↔ AB07
#
# AB082 ↔ AB083
#
# AB07 / AB081 / Normal มี cross เล็กน้อย
#
# 👉 นี่คือเหตุผลหลักที่ Top-k ช่วย

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
class_names = [
    'AB01','AB02','AB03','AB04','AB05','AB06','AB07',
    'AB081','AB082','AB083','AB09','AB10','AB11','AB12','Normal'
]
def topk_confusion_matrix(df, gt_col, pred_cols, k, labels):
    cm = np.zeros((len(labels), len(labels)))

    label_to_idx = {l:i for i,l in enumerate(labels)}

    for _, row in df.iterrows():
        gt = row[gt_col]
        preds = row[pred_cols[:k]].values.tolist()

        gt_idx = label_to_idx[gt]

        if gt in preds:
            # correct in Top-k → diagonal
            cm[gt_idx, gt_idx] += 1
        else:
            # miss → assign to Top-1 prediction
            pred1 = row[pred_cols[0]]
            pred_idx = label_to_idx[pred1]
            cm[gt_idx, pred_idx] += 1

    # normalize per GT class
    cm = cm / cm.sum(axis=1, keepdims=True)
    return cm
pred_15AB_cols = [
    'Unlearn_pred_15AB_top1',
    'Unlearn_pred_15AB_top2',
    'Unlearn_pred_15AB_top3',
    'Unlearn_pred_15AB_top4',
    'Unlearn_pred_15AB_top5'
]

cm_top1 = topk_confusion_matrix(
    Results_Unlearn, 'Sub_class_New', pred_15AB_cols, k=1, labels=class_names
)

cm_top3 = topk_confusion_matrix(
    Results_Unlearn, 'Sub_class_New', pred_15AB_cols, k=3, labels=class_names
)

cm_top5 = topk_confusion_matrix(
    Results_Unlearn, 'Sub_class_New', pred_15AB_cols, k=5, labels=class_names
)
def plot_cm(cm, labels, title):
    plt.figure(figsize=(8,7))
    plt.imshow(cm)
    plt.colorbar()
    plt.xticks(range(len(labels)), labels, rotation=45)
    plt.yticks(range(len(labels)), labels)
    plt.xlabel("Predicted label")
    plt.ylabel("Ground truth label")
    plt.title(title)
    plt.tight_layout()
    plt.show()
plot_cm(cm_top1, class_names, "15-class Confusion Matrix (Top-1)")
plot_cm(cm_top3, class_names, "15-class Confusion Matrix (Top-3)")
plot_cm(cm_top5, class_names, "15-class Confusion Matrix (Top-5)")

# %% [raw]
# 1️⃣ Confusion Matrix: Top-1
#
# ภาพรวม
#
# เส้นทแยง (diagonal) ชัดเจนหลายคลาส → โมเดลจำแนกได้ดีในคลาสหลัก
#
# คลาสที่เด่นมาก:
#
# AB05, AB09, AB11, AB12, Normal
# → ค่าใกล้ 1.0 แปลว่า precision/recall สูงมาก
#
# คลาสที่ยังสับสน:
#
# AB01 ↔ AB02 ↔ AB03
#
# AB06 ↔ AB07
#
# AB082 ↔ AB083
#
# Interpretation
#
# Top-1 ยัง “เข้มงวด” มาก ถ้าอันดับ 1 พลาดถือว่าผิดทันที
# เหมาะกับ use-case ที่ต้องการ single decision ชัดเจน
#
# 2️⃣ Confusion Matrix: Top-3
#
# สิ่งที่ดีขึ้นชัดเจน
#
# ค่า diagonal สว่างขึ้นเกือบทุกคลาส
#
# กลุ่มที่ดีขึ้นมาก:
#
# AB01, AB03, AB06, AB07
#
# AB082 / AB083 (sub-type ใกล้กัน)
#
# ความหมาย
#
# โมเดล “รู้คำตอบที่ถูก” แต่อาจยังไม่มั่นใจพอจะดันขึ้นเป็นอันดับ 1
# แต่คำตอบที่ถูกมักอยู่ใน 3 อันดับแรก
#
# 3️⃣ Confusion Matrix: Top-5
#
# ภาพรวม
#
# Diagonal เกือบทุกคลาสเข้าใกล้ 1.0
#
# คลาสยากแทบทั้งหมดถูกครอบคลุม
#
# Normal ยังคงเสถียร → ไม่มี false alarm เพิ่มแบบรุนแรง
#
# Interpretation เชิงระบบ
#
# สำหรับ AI-assisted diagnosis
# Top-5 คือ sweet spot เพราะ
#
# ลด False Negative
#
# ให้แพทย์เห็น candidate class ที่ “เป็นไปได้”

# %%
cm_diff = cm_top5 - cm_top1

plot_cm(
    cm_diff,
    class_names,
    "Difference Confusion Matrix (Top-5 − Top-1)"
)

# %% [raw]
# 1️⃣ ภาพรวมใหญ่ (Big picture)
#
# Top-5 เพิ่ม recall อย่างเป็นระบบเกือบทุกคลาส
# โดยเฉพาะคลาสที่ Top-1 มีความไม่มั่นใจสูง
#
# Diagonal เป็นสีเหลือง/เขียวเกือบทั้งหมด
# → Top-5 ช่วย “ดึงคำตอบที่ถูก” เข้ามาอยู่ใน candidate set
#
# Off-diagonal ส่วนใหญ่ใกล้ศูนย์
# → ไม่ได้เพิ่ม confusion แบบสุ่ม
#
# 2️⃣ คลาสที่ได้ประโยชน์สูงสุดจาก Top-5
#
# จาก diagonal ที่สว่างที่สุด:
#
# 🔥 Improvement สูงมาก
#
# AB03 (~ +0.26)
#
# AB06 (~ +0.24)
#
# AB01 (~ +0.23)
#
# AB082 / AB083
#
# AB07
#
# 📌 ตีความ:
#
# โมเดลมี representation ที่ “รู้จักคลาส” เหล่านี้ดี
# แต่ความมั่นใจยังแตกกระจาย → Top-5 แก้ปัญหานี้ได้ตรงจุด
#
# 3️⃣ Pattern ที่น่าสนใจมาก
# 🔁 Subtype confusion ที่ถูก “ควบคุม”
#
# AB082 ↔ AB083
#
# AB06 ↔ AB07
#
# จะเห็น:
#
# ค่าลบ (ม่วง) ในช่องสลับกัน
#
# แต่ diagonal บวกมากกว่าอย่างชัดเจน
#
# 👉 หมายความว่า:
#
# แม้ Top-5 จะเปิดพื้นที่ให้คลาสใกล้เคียง
# แต่สุดท้าย recall ของคลาสจริงเพิ่มสุทธิ
#
# นี่เป็นพฤติกรรมที่ “ดี” สำหรับ medical AI
#
# 4️⃣ Normal class: สัญญาณที่ดีมาก ✅
#
# Normal มีค่าเพิ่มเล็กน้อยแต่สม่ำเสมอ
#
# ไม่มี off-diagonal บวกแรง ๆ ไปคลาสผิด
#
# 📌 แปลว่า:
#
# Top-5 ไม่ทำให้ false alarm ของ Normal พุ่ง
# ซึ่งสำคัญมากใน screening system

# %%
cm_diff = cm_top3 - cm_top1

plot_cm(
    cm_diff,
    class_names,
    "Difference Confusion Matrix (Top-3 − Top-1)"
)

# %% [raw]
# ค่านี้ =
#
# Recall ต่อคลาสของ Top-3 − Recall ของ Top-1
#
# ค่าสีเหลือง / เขียว → Top-3 ดีขึ้นจาก Top-1
#
# ค่าสีม่วง / น้ำเงิน → มีการ trade-off (ย้าย prediction ไปคลาสอื่นมากขึ้น)
#
# 1️⃣ คลาสที่ได้ประโยชน์สูงจาก Top-3
#
# จาก diagonal ที่สว่างขึ้น:
#
# 🔥 ดีขึ้นชัดเจนมาก
#
# AB01 (~ +0.22)
#
# AB06 (~ +0.21)
#
# AB082
#
# AB03
#
# AB07
#
# 👉 ความหมาย:
#
# โมเดล “รู้คำตอบถูก” แต่ยังไม่มั่นใจพอจะดันขึ้น Top-1
# เมื่อเปิด Top-3 → recall กระโดดทันที
#
# เชิงคลินิก / application
#
# คลาสพวกนี้เป็น hard class
#
# Top-3 เหมาะมากสำหรับ decision support
#
# 2️⃣ กลุ่มที่ยังสับสนกัน (off-diagonal)
#
# เห็นชัดใน:
#
# AB06 ↔ AB07
#
# AB082 ↔ AB083
#
# AB01 ↔ AB02 ↔ AB03
#
# สีม่วงในบางช่อง =
#
# Top-3 เพิ่ม recall ของคลาสจริง แต่ก็เพิ่มโอกาสถูก “ดึงไปคลาสใกล้เคียง”
#
# 📌 นี่ไม่ใช่เรื่องแย่
# แต่สะท้อนว่า feature space overlap สูง
#
# 3️⃣ คลาสที่แทบไม่เปลี่ยน
#
# AB09, AB10, AB11, AB12, Normal
#
# → recall สูงอยู่แล้วตั้งแต่ Top-1
# → โมเดล confident มาก
#
# 🟢 ข้อดี:
#
# Normal ไม่โดน false alarm เพิ่ม
#
# คลาส severe / obvious จำแนกได้ตรง

# %% [markdown]
# ## Difference CM (Top-1 → Top-k heatmap)

# %% [markdown]
# Concept: Difference CM คืออะไร
#
# เราคำนวณ ΔCM=CMTop5−CMTop1
#
# โดย
#
# ใช้ row-normalized confusion matrix
#
# ค่า บวก (แดง) = ดีขึ้น
#
# ค่า ลบ (น้ำเงิน) = แย่ลง
#
# diagonal ↑ = recall ดีขึ้นต่อ class

# %%
def topk_confusion_label(row, gt_col, pred_cols, k):
    gt = row[gt_col]
    preds = row[pred_cols[:k]].values.tolist()

    if gt in preds:
        return gt
    else:
        return preds[0]   # fallback = top-1

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

def get_cm(df, gt_col, pred_cols, k, labels):
    y_true = df[gt_col]
    y_pred = df.apply(
        lambda r: topk_confusion_label(r, gt_col, pred_cols, k),
        axis=1
    )
    cm = confusion_matrix(
        y_true, y_pred,
        labels=labels,
        normalize="true"
    )
    return cm

# %%
labels_15AB = sorted(Results_Unlearn['Sub_class_New'].unique())

cm_top1 = get_cm(
    Results_Unlearn,
    gt_col="Sub_class_New",
    pred_cols=pred_15AB_columns_top5,
    k=1,
    labels=labels_15AB
)

cm_top5 = get_cm(
    Results_Unlearn,
    gt_col="Sub_class_New",
    pred_cols=pred_15AB_columns_top5,
    k=5,
    labels=labels_15AB
)

diff_cm = cm_top5 - cm_top1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(11,9))
sns.heatmap(
    diff_cm,
    xticklabels=labels_15AB,
    yticklabels=labels_15AB,
    cmap="coolwarm",
    center=0,
    annot=False
)
plt.xlabel("Predicted label")
plt.ylabel("Ground truth label")
plt.title("Difference Confusion Matrix (Top-5 − Top-1)")
plt.tight_layout()
plt.show()

# %%
import pandas as pd

recall_gain = np.diag(diff_cm)

recall_gain_df = pd.DataFrame({
    "Class": labels_15AB,
    "ΔRecall (Top5 - Top1)": recall_gain
}).sort_values("ΔRecall (Top5 - Top1)", ascending=False)

recall_gain_df
# Out:
#      Class  ΔRecall (Top5 - Top1)
# 0     AB01               0.229730
# 5     AB06               0.190476
# 9    AB083               0.181818
# 2     AB03               0.157895
# 8    AB082               0.142857
# 6     AB07               0.095238
# 1     AB02               0.050847
# 10    AB09               0.038462
# 14  Normal               0.037340
# 4     AB05               0.034483
# 7    AB081               0.031250
# 3     AB04               0.026316
# 11    AB10               0.000000
# 12    AB11               0.000000
# 13    AB12               0.000000

# %% [markdown]
# 1️⃣ Difference Confusion Matrix (Top-5 − Top-1)
#
# ความหมายของกราฟนี้
#
# สีแดง ➜ Top-5 ช่วยให้ทำนายถูก “มากขึ้น” เมื่อเทียบกับ Top-1
#
# สีน้ำเงิน ➜ บางกรณี Top-5 แย่ลง (พบได้น้อย / มักเกิดจาก normalization)
#
# ค่าใกล้ 0 ➜ แทบไม่เปลี่ยน
#
# สิ่งที่เห็นชัดมาก
#
# Diagonal สีแดงเด่นหลาย class
# 👉 แปลว่า Recall ต่อ class ดีขึ้นชัดเจน เมื่อใช้ Top-5
#
# Off-diagonal ส่วนใหญ่เป็นสีจาง
# 👉 Top-5 ไม่ได้เพิ่ม false positive เยอะ แต่ช่วย “ดึงของที่เกือบถูก” กลับมา
#
# Class ที่ได้ประโยชน์สูง
#
# AB03, AB06, AB07, AB082, AB083
#
# จากภาพ: diagonal แดงเข้ม
#
# หมายถึง โมเดลมักทำนายถูกอยู่ในอันดับ 2–5

# %%
labels_15AB = sorted(Results_Unlearn['Sub_class_New'].unique())

cm_top1 = get_cm(
    Results_Unlearn,
    gt_col="Sub_class_New",
    pred_cols=pred_15AB_columns_top5,
    k=1,
    labels=labels_15AB
)

cm_top5 = get_cm(
    Results_Unlearn,
    gt_col="Sub_class_New",
    pred_cols=pred_15AB_columns_top5,
    k=3,
    labels=labels_15AB
)

diff_cm = cm_top5 - cm_top1
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(11,9))
sns.heatmap(
    diff_cm,
    xticklabels=labels_15AB,
    yticklabels=labels_15AB,
    cmap="coolwarm",
    center=0,
    annot=False
)
plt.xlabel("Predicted label")
plt.ylabel("Ground truth label")
plt.title("Difference Confusion Matrix (Top-3 − Top-1)")
plt.tight_layout()
plt.show()

# %%
import pandas as pd

recall_gain = np.diag(diff_cm)

recall_gain_df = pd.DataFrame({
    "Class": labels_15AB,
    "ΔRecall (Top5 - Top1)": recall_gain
}).sort_values("ΔRecall (Top5 - Top1)", ascending=False)

recall_gain_df
# Out:
#      Class  ΔRecall (Top5 - Top1)
# 0     AB01               0.229730
# 5     AB06               0.190476
# 9    AB083               0.181818
# 2     AB03               0.157895
# 8    AB082               0.142857
# 6     AB07               0.095238
# 1     AB02               0.050847
# 10    AB09               0.038462
# 14  Normal               0.037340
# 4     AB05               0.034483
# 7    AB081               0.031250
# 3     AB04               0.026316
# 11    AB10               0.000000
# 12    AB11               0.000000
# 13    AB12               0.000000
